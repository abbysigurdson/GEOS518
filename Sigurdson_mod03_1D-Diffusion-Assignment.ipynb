# %% [markdown]
# # Module 03: Assignment for 1-D Diffusion Problem - Thawing Permafrost
#
# ### 1. Introduction and Background
#
# In this notebook you are going to investigate the impact of three climate change scenarios on our previously developed model of the vertical distribution of temperature in a permafrost soil.
#
#
# Again, the equation for 1-dimensional heat diffusion into a soil is presented below:
# $$
# \rho_s \cdot C_s \cdot \frac{\partial T_s}{\partial t} = \frac{\partial T_s}{\partial z}\left(k_s \cdot \frac{\partial T_s}{\partial z}\right)
# $$
#
# where $\rho_s$ (kg/m^3) is the bulk density of the soil, $C_s$ (J/(kg K)) is the heat capacity of the soil, $k_s$ (W/(m K)) is the thermal conductivity of the soil, $T_s$ is the temperature of the soil at some time $t$ and depth in the soil $z$. For the sake of simplicity, we're going to assume that the thermal conductivity is constant. This assumption is not strictly true, as $k_s$ changes with the amount and phase (frozen or liquid) of water in the soil. But it makes the math much simpler and is good starting point for a toy model. Under this assumption we can simplify the above equation to,
#
# $$
# \rho_s \cdot C_s \cdot \frac{\partial T_s}{\partial t} = k_s \frac{\partial T_s^2}{\partial^2 z}
# $$
#
# Going further, if we also assume that the bulk density ($rho_s$) and heat capacity ($C_s$) are constant, then we can combine them with the thermal conductivity and reduce them to a single parameter that is often referred to as the _thermal diffusivity_ ($D_s$) and has dimensions of m^2/s,
#
# $$
# D_s = \frac{k_s}{\rho_s \cdot C_s}
# $$
#
# Substituting into the above, we obtain the following governing equation that our model will solve,
#
# $$
# \frac{\partial T_s}{\partial t} = D_s \frac{\partial T_s^2}{\partial^2 z}
# $$
#
# Your __top boundary condition__, we will assume sinusoidal forcing of air temperature superimposed on a linear trend in mean annual temperatures at the surface, with a period of one year. In this notebook we will explore three scenarios. Scenario 1 is a linear increase in mean annual temperature at a rate that results in 1.5 °C of warming by 2100. Scenario 2 is a linear increase in mean annual temperature at a rate that results in 3.0 °C of warming by 2100. Scenario 3 is a linear increase in mean annual temperature at a rate that results in 4.5 °C of warming by 2100. We will start all simulations in 2020.
#
# Your __bottom boundary condition__, we will assume a constant temperature at the initial mean annual air temperature.
#
# Yur __initial condition__ will be a constant temperature (isothermal) at the mean annual air temperature. If interested you can copy this notebook and modify these values.
#
# ### 2. Initial Setup
#
# Below, we set the values for our spatial domain, simulation period, soil properties, and boundary conditions.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Soil column properties
zs = 500.0 # Depth of soil [cm]
dz = 15.0   # Numerical model layer thickness [cm]

# Soil properties (obtained from https://doi.org/10.1029/2017JF004535)
Cs = 635.0 # Heat capacity of soil/permafrost [J/(kg K)]
ks = 0.25  # Thermal conductivity of soil/permafrost [W/(m K)]
rhos = 920.0 # Bulk density of permafrost [kg/m^3] 

dt = 0.25 # Time step [day]

# %% [markdown]
# #### 2.1 Load and Plot the Air Temperature Trends

# %%
data = np.loadtxt('PermafrostTemperatureScenarios.csv', delimiter=',', skiprows=1)

t_year = data[:,0]
T_15 = data[:,1]
T_30 = data[:,2]
T_45 = data[:,3]

# %%
## First off, let's change the font size for all of our plots to be more legible
plt.rcParams.update({'font.size': 16})

plt.figure(figsize=(11.0,8.5))
plt.plot(t_year,T_15,label='$\Delta T$ = 1.5${}^{\circ}$C')
plt.plot(t_year,T_30,label='$\Delta T$ = 3.0${}^{\circ}$C')
plt.plot(t_year,T_45,label='$\Delta T$ = 4.5${}^{\circ}$C')
plt.legend(loc='upper left')
plt.grid()
plt.xlabel('Time [years]')
plt.ylabel('Annual average air temperature [°C]')
# Out:
# Text(0, 0.5, 'Annual average air temperature [°C]')

# %% [markdown]
# #### 2.2 Setup the Simulation Time Period

# %%
# Time properties of simulation
t0 = t_year[0]
tf = t_year[-1]

t = np.arange(t0,tf+(dt/365),(dt/365))
Nt = t.size
print('The number of time steps: Nt = ',str(Nt))
# Out:
# The number of time steps: Nt =  116801

# %% [markdown]
# ### 3. Setup Boundary Conditions

# %%
# Boundary conditions
Ttopamp = 35.0
Tbottom = -7.0

# %%
Ttop_15 = np.interp(t, t_year, T_15) + (Ttopamp/2.0)*np.sin((2.0*np.pi)*t)
Ttop_30 = np.interp(t, t_year, T_30) + (Ttopamp/2.0)*np.sin((2.0*np.pi)*t)
Ttop_45 = np.interp(t, t_year, T_45) + (Ttopamp/2.0)*np.sin((2.0*np.pi)*t)

plt.figure(figsize=(10.0,7.0))
plt.plot(t, Ttop_15, label='$\Delta T$ = 1.5${}^{\circ}$C')
plt.plot(t, Ttop_30, label='$\Delta T$ = 3.0${}^{\circ}$C')
plt.plot(t, Ttop_45, label='$\Delta T$ = 4.5${}^{\circ}$C')
plt.xlabel('Time [years]')
plt.ylabel('Daily air temperature [°C]')
plt.legend(loc='upper left')
plt.show()

# %% [markdown]
# ### 4. Setup Spatial Domain

# %%
z = np.arange(dz/2, zs, dz) # Array of depth of soil, starts at dz/2 with an interval of dz.
Nz = z.size # The size off array of z is the number of cells.
print('Here are the locations of our cells: z = \n' + str(z))
print('The number of cells is: Nz = ',str(Nz))
# Out:
# Here are the locations of our cells: z =
# [  7.5  22.5  37.5  52.5  67.5  82.5  97.5 112.5 127.5 142.5 157.5 172.5
#  187.5 202.5 217.5 232.5 247.5 262.5 277.5 292.5 307.5 322.5 337.5 352.5
#  367.5 382.5 397.5 412.5 427.5 442.5 457.5 472.5 487.5]
# The number of cells is: Nz =  33

# %% [markdown]
# ### 5. Setup Initial Condition

# %%
Ts0 = Tbottom*np.ones((Nz,1))

# %% [markdown]
# ### 6. Calculate $D$, $\mathbf{A}$, and $\mathbf{B}$ Matrices for Implicit or Crank-Nicolson Method

# %%
# Calculate diffusivity of permafrost soil
Ds = ks / (rhos * Cs)
print('Soil diffusivity = '+str(Ds)+' m^2/s\n')

# Convert alpha to units consistent with domain [cm^2/day]
Ds = Ds*(100.0**2)*(24.0*3600.0)
print('Soil diffusivity = '+str(Ds)+' cm^2/day\n')

alpha = Ds*dt/(dz**2)
print('Diffusion number '+str(alpha))

# Matrix A set up
# Creates a matrix size Nz with -2 along the main diagonal and 1 along the upper and lower diagonal.
Delta2 = np.diag(-2.0*np.ones((Nz))) + np.diag(np.ones((Nz-1)),1) + np.diag(np.ones((Nz-1)),-1)

# I is the identity matrix
I = np.eye(Nz)
A = I - alpha*Delta2 # Calculating A from Equation from section 2

# Setting BCs
A[0,:] = np.hstack((1.0,np.zeros((Nz-1)))) # A[0,:] = All of first row; np.hstack = first number = 1, the rest = 0.
A[-1,:] = np.hstack((np.zeros((Nz-1)),1.0)) # A[0,:] = All of last row; np.hstack = all except last = 0, last number = 1.
print(A)

# Calculating the inverse of matrix A
A_inv = np.linalg.pinv(A)
# Out:
# Soil diffusivity = 4.279356384799726e-07 m^2/s
#
# Soil diffusivity = 369.7363916466963 cm^2/day
#
# Diffusion number 0.41081821294077364
# [[ 1.          0.          0.         ...  0.          0.
#    0.        ]
#  [-0.41081821  1.82163643 -0.41081821 ...  0.          0.
#    0.        ]
#  [ 0.         -0.41081821  1.82163643 ...  0.          0.
#    0.        ]
#  ...
#  [ 0.          0.          0.         ...  1.82163643 -0.41081821
#    0.        ]
#  [ 0.          0.          0.         ... -0.41081821  1.82163643
#   -0.41081821]
#  [ 0.          0.          0.         ...  0.          0.
#    1.        ]]

# %% [markdown]
# ### 7. Preallocate Storage Memory

# %%
Ts_15 = np.zeros((Nz,Nt))
Ts_30 = np.zeros((Nz,Nt))
Ts_45 = np.zeros((Nz,Nt))

# %% [markdown]
# ### 8. Apply Solution And Compute Temperatures

# %%
# 1.5C increase in temperature
for i in np.arange(Nt):
    if(i==0):
        Tsi_15 = Ts0
    else:
        Tsi_15 = Ts_15[:,i-1]
        Tsi_15[0] = Ttop_15[i]
        Tsi_15[-1] = Tbottom
    
    Tsip1_15 = np.matmul(A_inv,Tsi_15)
    
    Ts_15[:,i] = np.squeeze(Tsip1_15)

# 3.0C increase in temperature    
for i in np.arange(Nt):
    if(i==0):
        Tsi_30 = Ts0
    else:
        Tsi_30 = Ts_30[:,i-1]
        Tsi_30[0] = Ttop_30[i]
        Tsi_30[-1] = Tbottom
    
    Tsip1_30 = np.matmul(A_inv,Tsi_30)
    
    Ts_30[:,i] = np.squeeze(Tsip1_30)

# 4.5C increase in temperature    
for i in np.arange(Nt):
    if(i==0):
        Tsi_45 = Ts0
    else:
        Tsi_45 = Ts_45[:,i-1]
        Tsi_45[0] = Ttop_45[i]
        Tsi_45[-1] = Tbottom
    
    Tsip1_45 = np.matmul(A_inv,Tsi_45)
    
    Ts_45[:,i] = np.squeeze(Tsip1_45)

# %% [markdown]
# ### 9. Plot Results, Analyze, and Interpret
#
# Create plots of the following:
#
# 1. A plot of 3 x 2 subplots of the vertical temperature distribution with time. Each row should correspond to each of the 3 climate change scenarios wiht the top row being the $\Delta T$ = 1.5${}^{\circ}$C, the middle being $\Delta T$ = 3.0${}^{\circ}$C, and the bottom row being $\Delta T$ = 4.5${}^{\circ}$C. The left column should correspond to the ___first___ 10 years of simulation, and the right column the ___last___ 10 years of simulation.
# 2. A plot of 2 x 2 subplots of the temperature at four different levels. One subplot of temperature versus time for all three scenarios at a depth of 50 cm, the second subplot the same information at 100 cm, the third subplot the same information at 200 cm, and the fourth subplot the same information at 400 cm.
# 3. A markdown table showing the approximate depth of the active layer for each scenario for the first, a middle, and the final decade of the simulation.

# %% [markdown]
# ### 9.1 Results

# %%
# Defining the 1st 10 years and last 10 years of simulation
t2030 = t[0:14600]
t2100 = t[102201:-1]

# Defining temperature indices
Ts2030_15 = Ts_15[:,0:14600]
Ts2100_15 = Ts_15[:,102201:-1]

Ts2030_30 = Ts_30[:,0:14600]
Ts2100_30 = Ts_30[:,102201:-1]

Ts2030_45 = Ts_45[:,0:14600]
Ts2100_45 = Ts_45[:,102201:-1]

# Create meshgrid
tt_i,zz_i = np.meshgrid(t2030,z)
tt_f,zz_f = np.meshgrid(t2100,z)

plt.figure(figsize=(20,25))
plt.rcParams.update({'font.size': 14})

# Plot of first 10 years with first scenario (1.5C)
plt.subplot(3,2,1) 
plt.pcolormesh(tt_i,-zz_i,Ts2030_15,cmap='inferno',shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 1, First Decade')

# Plot of last 10 years with first scenario (1.5C)
plt.subplot(3,2,2) 
plt.pcolormesh(tt_f,-zz_f,Ts2100_15,cmap='inferno',shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 1, Last Decade')

# Plot of first 10 years with second scenario (3.0C)
plt.subplot(3,2,3) 
plt.pcolormesh(tt_i,-zz_i,Ts2030_30,cmap='inferno',shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 2, First Decade')

# Plot of last 10 years with third scenario (3.0C)
plt.subplot(3,2,4) 
plt.pcolormesh(tt_f,-zz_f,Ts2100_30,cmap='inferno',shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 2, Last Decade')

# Plot of first 10 years with third scenario (4.5C)
plt.subplot(3,2,5) 
plt.pcolormesh(tt_i,-zz_i,Ts2030_45,cmap='inferno',shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 3, First Decade')

# Plot of last 10 years with third scenario (4.5C)
plt.subplot(3,2,6) 
plt.pcolormesh(tt_f,-zz_f,Ts2100_45,cmap='inferno',shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 3, Last Decade')
# Out:
# Text(0.5, 1.0, 'Scenario 3, Last Decade')

# %% [markdown]
# ### 9.2 Results

# %%
# Determine depths
iz50 = (np.absolute(z-50.0)).argmin()
iz100 = (np.absolute(z-100.0)).argmin()
iz200 = (np.absolute(z-200.0)).argmin()
iz400 = (np.absolute(z-400.0)).argmin()

plt.figure(figsize=(20,25))
plt.rcParams.update({'font.size': 14})


#50m depth
plt.subplot(2,2,1)
plt.plot(t,Ts_15[iz50,:],label='Scenario 1')
plt.plot(t,Ts_30[iz50,:],label='Scenario 2')
plt.plot(t,Ts_45[iz50,:],label='Scenario 3')
plt.xlabel('Time [years]')
plt.ylabel('Soil Temperature [°C]')
plt.legend()
plt.title('Scenarios at a Depth of 50m')

#100m depth
plt.subplot(2,2,2)
plt.plot(t,Ts_15[iz100,:],label='Scenario 1')
plt.plot(t,Ts_30[iz100,:],label='Scenario 2')
plt.plot(t,Ts_45[iz100,:],label='Scenario 3')
plt.xlabel('Time [years]')
plt.ylabel('Soil Temperature [°C]')
plt.legend()
plt.title('Scenarios at a Depth of 100m')

#200m depth
plt.subplot(2,2,3)
plt.plot(t,Ts_15[iz200,:],label='Scenario 1')
plt.plot(t,Ts_30[iz200,:],label='Scenario 2')
plt.plot(t,Ts_45[iz200,:],label='Scenario 3')
plt.xlabel('Time [years]')
plt.ylabel('Soil Temperature [°C]')
plt.legend()
plt.title('Scenarios at a Depth of 200m')

#400m depth
plt.subplot(2,2,4)
plt.plot(t,Ts_15[iz400,:],label='Scenario 1')
plt.plot(t,Ts_30[iz400,:],label='Scenario 2')
plt.plot(t,Ts_45[iz400,:],label='Scenario 3')
plt.xlabel('Time [years]')
plt.ylabel('Soil Temperature [°C]')
plt.legend()
plt.title('Scenarios at a Depth of 200m')
# Out:
# Text(0.5, 1.0, 'Scenarios at a Depth of 200m')

# %% [markdown]
# ### 9.3 Results

# %%
# Defining where values are above 0C
Ts_frozen15 = np.ma.masked_where(Ts_15>0.0,Ts_15)
Ts_frozen30 = np.ma.masked_where(Ts_30>0.0,Ts_30)
Ts_frozen45 = np.ma.masked_where(Ts_45>0.0,Ts_45)

# Defining the middle 10 years and last 10 years of simulation
t2060 = t[43800:58400]

# Defining temperature indices
Ts_frozen15_2030 = Ts_frozen15[:,0:14600]
Ts_frozen30_2030 = Ts_frozen30[:,0:14600]
Ts_frozen45_2030 = Ts_frozen45[:,0:14600]

Ts_frozen15_2060 = Ts_frozen15[:,43800:58400]
Ts_frozen30_2060 = Ts_frozen30[:,43800:58400]
Ts_frozen45_2060 = Ts_frozen45[:,43800:58400]

Ts_frozen15_2100 = Ts_frozen15[:,102201:-1]
Ts_frozen30_2100 = Ts_frozen30[:,102201:-1]
Ts_frozen45_2100 = Ts_frozen45[:,102201:-1]

# Create meshgrid
tt_m,zz_m = np.meshgrid(t2060,z)

plt.figure(figsize=(30,30))
plt.rcParams.update({'font.size': 14})

# Plot of first 10 years with first scenario (1.5C)
plt.subplot(3,3,1) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_i,-zz_i,Ts_frozen15_2030,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 1, First Decade')

# Plot of mid 10 years with first scenario (1.5C)
plt.subplot(3,3,2) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_m,-zz_m,Ts_frozen15_2060,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 1, Middle Decade')

# Plot of last 10 years with second scenario (1.5C)
plt.subplot(3,3,3) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_f,-zz_f,Ts_frozen15_2100,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 1, Last Decade')

# Plot of first 10 years with second scenario (3.0C)
plt.subplot(3,3,4) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_i,-zz_i,Ts_frozen30_2030,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 2, First Decade')

# Plot of mid 10 years with second scenario (3.0C)
plt.subplot(3,3,5) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_m,-zz_m,Ts_frozen30_2060,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 2, Middle Decade')

# Plot of last 10 years with second scenario (3.0C)
plt.subplot(3,3,6) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_f,-zz_f,Ts_frozen30_2100,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 2, Last Decade')

# Plot of first 10 years with third scenario (4.5C)
plt.subplot(3,3,7) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_i,-zz_i,Ts_frozen45_2030,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 3, First Decade')

# Plot of mid 10 years with third scenario (4.5C)
plt.subplot(3,3,8) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_m,-zz_m,Ts_frozen45_2060,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 3, Middle Decade')

# Plot of last 10 years with third scenario (4.5C)
plt.subplot(3,3,9) 
current_cmap = plt.cm.get_cmap('inferno')
current_cmap.set_bad(color='blue')
plt.pcolormesh(tt_f,-zz_f,Ts_frozen45_2100,cmap=current_cmap,shading='auto') 
plt.colorbar(label= '$T_s$ [°C]')
plt.xlabel('Time [years]')
plt.ylabel('Soil Depth [cm]')
plt.title('Scenario 3, Last Decade')
# Out:
# <ipython-input-25-8ae68ee001c0>:31: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:41: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:51: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:61: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:71: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:81: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:91: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:101: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# <ipython-input-25-8ae68ee001c0>:111: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("inferno"))
#   current_cmap.set_bad(color='blue')
# Text(0.5, 1.0, 'Scenario 3, Last Decade')

# %% [markdown]
# #### Table 1: Approximate Active Layer for the Given Scenarios and Decades
# Scenario|2020-2030 Approximate Active Layer|2050-2060 Approximate Active Layer|2090-2100 Approximate Active Layer
# :-:|:-:|:-:|:-:
# 1.5 °C|205 cm|225 cm|250 cm
# 3.0 °C|210 cm|240 cm|260 cm
# 4.5 °C|210 cm|250 cm|270 cm
